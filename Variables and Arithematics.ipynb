# %%
a = 7.1
b = 0

a + b*2
# Out:
# 7.1

# %%
mike = 17

print(mike*b + 1)
print(mike**b)
# Out:
# 1
# 1

# %%
greeting = 'Hello. My name is '
name = 'Lynne'
age = 22

print(greeting + name + '!')
print('I am ' + str(age) + ' years old.')
# Out:
# Hello. My name is Lynne!
# I am 22 years old.

# %%
# assignment!

print('My name is ' + name + '. I am now ' + str(age) + ' years old,\
       and in 6 years I\'ll be ' +str(age+6)+ ' years old.')
# Out:
# My name is Lynne. I am now 22 years old,       and in 6 years I'll be 28 years old.
